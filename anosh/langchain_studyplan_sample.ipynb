# %% [markdown]
# # LangChain Study Plan Approval Sample Project
#
# Setting up a minimal notebook using university study plan approval use-case.

# %%
# Install dependencies (run as code cell)
# !python -m pip install --upgrade pip
# !pip install langchain
# Optional, for structured validation
# !pip install pydantic-ai
# !pip install -U langchain-perplexity
# Out:
# Requirement already satisfied: pip in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (25.2)
# Requirement already satisfied: langchain in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (1.0.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.0.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.0.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (0.4.37)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain) (2.4)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (1.0.1)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.0->langchain) (1.11.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (4.11.0)
# Requirement already satisfied: certifi in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (3.4)
# Requirement already satisfied: h11>=0.16 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (3.3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.0.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (1.3.0)
# Requirement already satisfied: pydantic-ai in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (1.2.1)
# Requirement already satisfied: pydantic-ai-slim==1.2.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.2.1)
# Requirement already satisfied: genai-prices>=0.0.31 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.0.35)
# Requirement already satisfied: griffe>=1.3.2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.14.0)
# Requirement already satisfied: httpx>=0.27 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.28.1)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.38.0)
# Requirement already satisfied: pydantic-graph==1.2.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.2.1)
# Requirement already satisfied: pydantic>=2.10 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.11.7)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.4.1)
# Requirement already satisfied: ag-ui-protocol>=0.1.8 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.1.9)
# Requirement already satisfied: starlette>=0.45.3 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.48.0)
# Requirement already satisfied: anthropic>=0.70.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.71.0)
# Requirement already satisfied: boto3>=1.39.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.40.56)
# Requirement already satisfied: argcomplete>=3.5.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (3.6.3)
# Requirement already satisfied: prompt-toolkit>=3 in c:\users\anbil\appdata\roaming\python\python311\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (3.0.39)
# Requirement already satisfied: pyperclip>=1.9.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.11.0)
# Requirement already satisfied: rich>=13 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (13.9.4)
# Requirement already satisfied: cohere>=5.18.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (5.19.0)
# Requirement already satisfied: pydantic-evals==1.2.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.2.1)
# Requirement already satisfied: google-genai>=1.31.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.46.0)
# Requirement already satisfied: groq>=0.25.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.33.0)
# Requirement already satisfied: huggingface-hub>=0.33.5 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.35.3)
# Requirement already satisfied: logfire>=3.14.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (4.14.1)
# Requirement already satisfied: mcp>=1.12.3 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.18.0)
# Requirement already satisfied: mistralai>=1.9.10 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.9.11)
# Requirement already satisfied: openai>=1.107.2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.6.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (9.1.2)
# Requirement already satisfied: temporalio==1.18.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.18.0)
# Requirement already satisfied: google-auth>=2.36.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.41.1)
# Requirement already satisfied: requests>=2.32.2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.32.4)
# Requirement already satisfied: anyio>=0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-evals==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (4.11.0)
# Requirement already satisfied: logfire-api>=3.14.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-evals==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (4.14.1)
# Requirement already satisfied: pyyaml>=6.0.2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-evals==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (6.0.3)
# Requirement already satisfied: nexus-rpc==1.1.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from temporalio==1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.1.0)
# Requirement already satisfied: protobuf<7.0.0,>=3.20 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from temporalio==1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (6.33.0)
# Requirement already satisfied: types-protobuf>=3.20 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from temporalio==1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (6.32.1.20250918)
# Requirement already satisfied: typing-extensions<5,>=4.2.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from temporalio==1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.10->pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.10->pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.33.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from anthropic>=0.70.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from anthropic>=0.70.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.17.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from anthropic>=0.70.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from anthropic>=0.70.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from anyio>=0->pydantic-evals==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (3.4)
# Requirement already satisfied: certifi in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27->pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27->pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.27->pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.16.0)
# Requirement already satisfied: botocore<1.41.0,>=1.40.56 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.40.56)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from botocore<1.41.0,>=1.40.56->boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from botocore<1.41.0,>=1.40.56->boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.0.7)
# Requirement already satisfied: six>=1.5 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.56->boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.16.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from cohere>=5.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.12.1)
# Requirement already satisfied: httpx-sse==0.4.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from cohere>=5.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.4.0)
# Requirement already satisfied: tokenizers<1,>=0.15 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from cohere>=5.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.21.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from cohere>=5.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.32.4.20250913)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.32.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (3.3.1)
# Requirement already satisfied: filelock in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (24.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (4.67.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=2.36.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=2.36.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=2.36.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.36.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from google-genai>=1.31.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (15.0.1)
# Requirement already satisfied: colorama>=0.4 in c:\users\anbil\appdata\roaming\python\python311\site-packages (from griffe>=1.3.2->pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.4.6)
# Requirement already satisfied: aiohttp in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (3.9.4)
# Requirement already satisfied: executing>=2.0.1 in c:\users\anbil\appdata\roaming\python\python311\site-packages (from logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.0.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<1.39.0,>=1.35.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.38.0)
# Requirement already satisfied: opentelemetry-instrumentation>=0.41b0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.59b0)
# Requirement already satisfied: opentelemetry-sdk<1.39.0,>=1.35.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.38.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<1.39.0,>=1.35.0->logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.71.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<1.39.0,>=1.35.0->logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<1.39.0,>=1.35.0->logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.38.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api>=1.28.0->pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (8.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.28.0->pydantic-ai-slim==1.2.1->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (3.19.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-sdk<1.39.0,>=1.35.0->logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-httpx>=0.42b0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.59b0)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.7.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (3.0.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.38.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.12.0)
# Requirement already satisfied: eval-type-backport>=0.2.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from mistralai>=1.9.10->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.2.2)
# Requirement already satisfied: invoke<3.0.0,>=2.2.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from mistralai>=1.9.10->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.2.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation>=0.41b0->logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.16.0)
# Requirement already satisfied: opentelemetry-util-http==0.59b0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-httpx>=0.42b0->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.59b0)
# Requirement already satisfied: wcwidth in c:\users\anbil\appdata\roaming\python\python311\site-packages (from prompt-toolkit>=3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.2.8)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings>=2.5.2->mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from rich>=13->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\anbil\appdata\roaming\python\python311\site-packages (from rich>=13->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (0.1.2)
# Requirement already satisfied: click>=7.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from uvicorn>=0.31.1->mcp>=1.12.3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (8.1.7)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,vertexai]==1.2.1->pydantic-ai) (1.9.4)
# Collecting langchain-perplexity
#   Downloading langchain_perplexity-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-perplexity) (1.0.0)
# Requirement already satisfied: openai<3.0.0,>=2.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-perplexity) (2.6.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (0.4.37)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (2.11.7)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (2.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (0.25.0)
# Requirement already satisfied: anyio in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (4.11.0)
# Requirement already satisfied: certifi in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (1.0.9)
# Requirement already satisfied: idna in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (3.4)
# Requirement already satisfied: h11>=0.16 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=2.0.0->langchain-perplexity) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=2.0.0->langchain-perplexity) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=2.0.0->langchain-perplexity) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=2.0.0->langchain-perplexity) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (3.3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anbil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-perplexity) (2.0.7)
# Requirement already satisfied: colorama in c:\users\anbil\appdata\roaming\python\python311\site-packages (from tqdm>4->openai<3.0.0,>=2.0.0->langchain-perplexity) (0.4.6)
# Downloading langchain_perplexity-1.0.0-py3-none-any.whl (8.4 kB)
# Installing collected packages: langchain-perplexity
# Successfully installed langchain-perplexity-1.0.0

# %%
import os
from typing import Literal
from langchain_perplexity import ChatPerplexity
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field
from pprint import pprint

import getpass

if "PPLX_API_KEY" not in os.environ:
    os.environ["PPLX_API_KEY"] = getpass.getpass("Enter your Perplexity API key: ")

# %% [markdown]
# ## Minimal Agent Example
#
# A structured evaluation output format study plan input and simulate a minimal agent's output.

# %%
class StudyPlanEvaluation(BaseModel):
    """
    Represents the evaluation of a student's study plan.
    """
    decision: Literal["GREEN", "YELLOW", "RED"] = Field(
        description="The final decision score for the plan."
    )
    reasoning: str = Field(
        description="A brief, point-by-point explanation for the decision, referencing the criteria."
    )
    alignment_ok: bool = Field(
        description="Whether the courses align with the student's specialization."
    )
    scheduling_ok: bool = Field(
        description="Whether there are any scheduling or exam conflicts."
    )

# %% [markdown]
# Knowledge base and input prompt

# %%
KNOWLEDGE_BASE = """
# University Rules & Evaluation Criteria

## 1. Core Requirements
- A study plan must cover at least two semesters (one year).
- The evaluation must check for Scheduling conflicts, Alignment with specialization, and overall Workload.

## 2. Scoring System
- **GREEN**: Approved. The plan is perfect with no issues.
- **YELLOW**: Human Review Required. The plan has minor issues or potential risks that require a final decision from a human.
- **RED**: Rejected. The plan has critical faults in one or more criteria.

## 3. Course & Specialization Data
- **Specialization Blocks**:
  - Data Science: Requires courses 'CS501: Advanced Algorithms', 'CS502: Machine Learning', 'CS503: Big Data Analytics'.
  - Software Engineering: Requires courses 'SE501: Software Architecture', 'SE502: System Design', 'SE503: DevOps'.

## 4. Scheduling Constraints
- **Known Conflicts**:
  - 'CS501: Advanced Algorithms' lecture (Mon 10:00-12:00) conflicts with 'SE502: System Design' exercise (Mon 11:00-12:00).
- **Exam Spacing**:
  - A minimum of 3 full days is recommended between any two exam dates.
"""

STUDY_PLAN = """
# Student Study Plan Submission

- **Student Name**: Jane Doe
- **Specialization**: Data Science
- **Plan for Semesters**: Fall 2026, Spring 2027
- **Courses**:
  - 'CS501: Advanced Algorithms' (Exam: 2027-02-15)
  - 'CS502: Machine Learning' (Exam: 2027-02-20)
  - 'SE502: System Design' (Exam: 2027-03-10)
"""

prompt_template = ChatPromptTemplate.from_messages([
    ("system",
     "You are an expert university administrator who approves student study plans. "
     "You must strictly follow the provided knowledge base to evaluate the plan. "
     "Your response must be structured according to the provided schema."
     "Reasoning must be concise and point-wise."),
    ("human",
     "Here is the knowledge base:\n--- KNOWLEDGE BASE ---\n{knowledge_base}\n\n"
     "Evaluate this study plan:\n--- STUDY PLAN ---\n{study_plan}")])

# %%
llm = ChatPerplexity(
    model="sonar",
    temperature=0.2
)
structured_llm = llm.with_structured_output(StudyPlanEvaluation)

# Create the Chain using Langchain Expression Language (LCEL)
# The '|' operator creates a seamless chain from prompt to model.
chain = prompt_template | structured_llm

# %%
# Run the Chain and Get the Structured Evaluation
def evaluate_plan_structured():
    """
    Runs the chain and prints the resulting Pydantic object.
    """
    
    # The chain's 'invoke' method runs the evaluation.
    response_object = chain.invoke({
        "knowledge_base": KNOWLEDGE_BASE,
        "study_plan": STUDY_PLAN
    })

    print("\n--- Study Plan Evaluation Result ---")
    print(f"Decision: {response_object.decision}")
    pprint(f"Reasoning: {response_object.reasoning}")
    print(f"Alignment OK: {response_object.alignment_ok}")
    print(f"Scheduling OK: {response_object.scheduling_ok}")
    print(f"\nType of response: {type(response_object)}")

# %%
for _ in range(5):
    print("\n==============================\n")
    evaluate_plan_structured()
# Out:
# ==============================
#
#
# --- Study Plan Evaluation Result ---
# Decision: YELLOW
# ('Reasoning: 1. The study plan covers two semesters (Fall 2026 and Spring '
#  '2027), satisfying the minimum duration requirement. 2. The student’s '
#  'specialization is Data Science, which requires courses CS501, CS502, and '
#  'CS503. The plan includes CS501 and CS502 but lacks CS503, so the '
#  'specialization alignment is incomplete. 3. There is a known scheduling '
#  'conflict between CS501 lecture and SE502 exercise on Mondays 10:00-12:00 and '
#  '11:00-12:00 respectively; since both courses are in the plan, this conflict '
#  'exists. 4. Exam spacing is adequate with at least 3 full days between exams '
#  '(Feb 15, Feb 20, Mar 10). 5. Overall workload and semester coverage are '
#  'acceptable. Due to the missing required course for the specialization and '
#  'the scheduling conflict, the plan has minor but critical issues requiring '
#  'human review.')
# Alignment OK: False
# Scheduling OK: False
#
# Type of response: <class '__main__.StudyPlanEvaluation'>
#
# ==============================
#
#
# --- Study Plan Evaluation Result ---
# Decision: YELLOW
# ('Reasoning: 1. The study plan covers two semesters (Fall 2026 and Spring '
#  '2027), meeting the core requirement for duration. 2. The courses include '
#  "'CS501: Advanced Algorithms' and 'CS502: Machine Learning', which are "
#  'required for the Data Science specialization, so the plan aligns with the '
#  "student's specialization. However, it also includes 'SE502: System Design', "
#  'which is not part of the Data Science specialization and belongs to Software '
#  'Engineering, indicating partial misalignment. 3. There is a known scheduling '
#  "conflict between 'CS501' lecture and 'SE502' exercise on Mondays 10:00-12:00 "
#  'and 11:00-12:00 respectively, which applies here and is a critical fault. 4. '
#  'Exam spacing is adequate with at least 3 full days between exams (Feb 15, '
#  'Feb 20, Mar 10). 5. Due to the critical scheduling conflict and partial '
#  'misalignment with specialization, the plan cannot be fully approved and '
#  'requires human review for possible adjustments or exceptions.')
# Alignment OK: False
# Scheduling OK: False
#
# Type of response: <class '__main__.StudyPlanEvaluation'>
#
# ==============================
#
#
# --- Study Plan Evaluation Result ---
# Decision: RED
# ('Reasoning: The study plan is rejected due to a critical scheduling conflict '
#  'and a specialization alignment issue.')
# Alignment OK: False
# Scheduling OK: False
#
# Type of response: <class '__main__.StudyPlanEvaluation'>
#
# ==============================
#
#
# --- Study Plan Evaluation Result ---
# Decision: YELLOW
# ('Reasoning: 1. The study plan covers two semesters (Fall 2026 and Spring '
#  '2027), satisfying the core requirement for duration. 2. The student’s '
#  'specialization is Data Science, which requires courses CS501, CS502, and '
#  'CS503. The plan includes CS501 and CS502 but lacks CS503, indicating '
#  'incomplete alignment with the specialization requirements. 3. There is a '
#  'known scheduling conflict between CS501 lecture and SE502 exercise on '
#  'Mondays 10:00-12:00 and 11:00-12:00 respectively. Since both courses are '
#  'included, this conflict exists in the plan. 4. Exam dates are spaced with 5 '
#  'days between CS501 and CS502 exams, and 18 days between CS502 and SE502 '
#  'exams, which meets the minimum 3 full days spacing rule. 5. The inclusion of '
#  'SE502, a Software Engineering course, is not aligned with the Data Science '
#  'specialization requirements and may represent a workload or focus issue. Due '
#  'to the missing required course CS503 and the scheduling conflict, the plan '
#  'has minor but significant issues requiring human review.')
# Alignment OK: False
# Scheduling OK: False
#
# Type of response: <class '__main__.StudyPlanEvaluation'>
#
# ==============================
#
#
# --- Study Plan Evaluation Result ---
# Decision: YELLOW
# ('Reasoning: 1. The study plan covers two semesters (Fall 2026, Spring 2027), '
#  'meeting the minimum duration requirement. 2. The student’s specialization is '
#  'Data Science, which requires courses CS501, CS502, and CS503. The plan '
#  'includes CS501 and CS502 but lacks CS503, indicating incomplete alignment '
#  'with the specialization requirements. 3. There is a known scheduling '
#  'conflict between CS501 lecture and SE502 exercise on Mondays 10:00-12:00 and '
#  '11:00-12:00 respectively; since both courses are in the plan, this is a '
#  'critical scheduling conflict. 4. Exam dates are spaced as follows: CS501 on '
#  '2027-02-15, CS502 on 2027-02-20 (5 days apart), and SE502 on 2027-03-10, so '
#  'exam spacing is adequate with at least 3 full days between exams. 5. Overall '
#  'workload is not explicitly stated but the plan includes three courses over '
#  'two semesters, which is reasonable. Due to the critical scheduling conflict '
#  'and incomplete specialization alignment, the plan requires human review '
#  'before approval.')
# Alignment OK: False
# Scheduling OK: False
#
# Type of response: <class '__main__.StudyPlanEvaluation'>
